# %%
# %reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
#%matplotlib inline
df = pd.read_csv('log3.txt', sep = " ")

df = df.drop(columns=['folder'])
df.sort_values(by='mIoU_aver', inplace=True)
df.reset_index(inplace=True, drop=True)
#df['mIoU_aver'] = pd.to_numeric(df['mIoU_aver'].replace('?', np.nan))
df['mIoU_aver'] = pd.cut(df['mIoU_aver'], [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0])


#df.drop(columns=['folder'])

from matplotlib import ticker

# cols = list(df.columns)
# print(cols)
#df.drop('mIoU_aver', axis='columns', inplace=True) #['displacement', 'cylinders', 'horsepower', 'weight', 'acceleration']

# df.drop('IoU_other_aver', axis='columns', inplace=True)
# df.drop('IoU_ground_aver', axis='columns', inplace=True)
# df.drop('IoU_bui_aver', axis='columns', inplace=True)
# df.drop('mIoU_var', axis='columns', inplace=True)
# df.drop('IoU_other_var', axis='columns', inplace=True)
# df.drop('IoU_ground_var', axis='columns', inplace=True)
# df.drop('IoU_bui_var', axis='columns', inplace=True)
# df.drop('acc_aver', axis='columns', inplace=True)
# df.drop('acc_var', axis='columns', inplace=True)
# df.drop('threads', axis='columns', inplace=True)

# df.drop('fsd', axis='columns', inplace=True)
# df.drop('rep_ext', axis='columns', inplace=True)
# df.drop('kp_ext', axis='columns', inplace=True)
# df.drop('max_epoch', axis='columns', inplace=True)
# df.drop('steps_per_epoch', axis='columns', inplace=True)


cols = list(df.columns)
print(cols)
#cols.remove('index')

cols.remove('mIoU_aver') #['displacement', 'cylinders', 'horsepower', 'weight', 'acceleration']
cols.remove('IoU_other_aver')
cols.remove('IoU_ground_aver')
cols.remove('IoU_bui_aver')
cols.remove('mIoU_var')
cols.remove('IoU_other_var')
cols.remove('IoU_ground_var')
cols.remove('IoU_bui_var')
cols.remove('acc_aver')
cols.remove('acc_var')
cols.remove('threads')
cols.remove('max_epoch')
cols.remove('steps_per_epoch')
print(df)
print(cols)

x = [i for i, _ in enumerate(cols)]

colours_list = ['#EEEEEE', '#E7E7E7', '#DDDDDD', '#D7D7D7', '#999999', '#777777', '#555555', '#333333', '#000000', '#000000' ]
#colours_list = ['#000000', '#111111', '#222222', '#333333', '#444444', '#555555', '#666666', '#777777', '#888888', '#999999' ]
#colours_list = ['#000000', '#AA0000', '#00AA00', '#0000AA', '#00AAAA', '#AA00AA', '#AAAA00', '#A0A0A0', '#0A0A0A', '#AAA000' ]
#colours_list = ['#000000', '#AA0000', '#00AA00', '#0000AA', '#00AAAA', '#AA00AA']
# colours = {}
# for i, _ in enumerate(df['mIoU_aver'].cat.categories):
#     colours[df['mIoU_aver'].cat.categories[i]].append(colours_list[i])
# colours = {}
# for i, _ in enumerate(df['mIoU_aver'].cat.categories):
#     print(i)
#     colours[df['mIoU_aver'].cat.categories[i]] = colours_list[i]
    
# create dict of categories: colours
colours = {df['mIoU_aver'].cat.categories[i]: colours_list[i] for i, _ in enumerate(df['mIoU_aver'].cat.categories)}
colours
# Create (X-1) sublots along x axis
fig, axes = plt.subplots(1, len(x)-1, sharey=False, linewidth=30, figsize=(15,5))

# Get min, max and range for each column
# Normalize the data for each column
min_max_range = {}
for col in cols:
    #print('col', col)
    min_max_range[col] = [df[col].min(), df[col].max(), np.ptp(df[col])]
    #print('min_max_range[col]', min_max_range[col]) 
    df[col] = np.true_divide(df[col] - df[col].min(), np.ptp(df[col]))
    #print('df[col]')
    #print(df[col])

for idx in df.index:
    df.loc[idx, cols] = df.loc[idx, cols] + 0.001 * (idx - int(len(df.index)/2))
    #print(idx, idx - int(len(df.index)/2), df.loc[idx, cols])
    
#print(df)

# Plot each row
for i, ax in enumerate(axes):
    for idx in df.index:
        #print(df.loc[idx, cols[i]], ax, i)
        #df.loc[idx, cols[i]] += 0.05
        mpg_category = df.loc[idx, 'mIoU_aver']
        ax.plot(x, df.loc[idx, cols], colours[mpg_category], linewidth=0.2)
        #print(df.loc[idx, cols], colours[mpg_category])
    ax.set_xlim([x[i], x[i+1]])
    
# Set the tick positions and labels on y axis for each plot
# Tick positions based on normalised data
# Tick labels are based on original data
def set_ticks_for_axis(dim, ax, ticks):
    min_val, max_val, val_range = min_max_range[cols[dim]]
    print('min_val, max_val, val_range', min_val, max_val, val_range)
    step = val_range / float(ticks-1)
    tick_labels = [round(min_val + step * i, 2) for i in range(ticks)]
    norm_min = df[cols[dim]].min()
    norm_range = np.ptp(df[cols[dim]])
    norm_step = norm_range / float(ticks-1)
    print('norm_min, norm_range, norm_step', norm_min, norm_range, norm_step)
    ticks = [round(norm_min + norm_step * i, 2) for i in range(ticks)]
    ax.yaxis.set_ticks(ticks)
    ax.set_yticklabels(tick_labels)

for dim, ax in enumerate(axes):
    ax.xaxis.set_major_locator(ticker.FixedLocator([dim]))
    set_ticks_for_axis(dim, ax, ticks=6)
    ax.set_xticklabels([cols[dim]])
    

# Move the final axis' ticks to the right-hand side
ax = plt.twinx(axes[-1])
dim = len(axes)
ax.xaxis.set_major_locator(ticker.FixedLocator([x[-2], x[-1]]))
set_ticks_for_axis(dim, ax, ticks=6)
ax.set_xticklabels([cols[-2], cols[-1]])


# Remove space between subplots
plt.subplots_adjust(wspace=0)

# Add legend to plot
plt.legend(
    [plt.Line2D((0,1),(0,0), color=colours[cat]) for cat in df['mIoU_aver'].cat.categories],
    df['mIoU_aver'].cat.categories,
    bbox_to_anchor=(1.2, 1), loc=2, borderaxespad=0.)

plt.title("Values of mIoU_aver")

plt.show()
fig.savefig('graph.png', dpi=1200)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
# ['fsd', 'in_rad', 'conv_rad', 'def_rad', 'rep_ext', 'kp_ext', 'num_ker_pts', 'def_fit_power', 'max_epoch', 'steps_per_epoch', 'threads', 'acc_aver', 'acc_var', 'mIoU_aver', 'IoU_other_aver', 'IoU_ground_aver', 'IoU_bui_aver', 'mIoU_var', 'IoU_other_var', 'IoU_ground_var', 'IoU_bui_var']
#      fsd  in_rad  conv_rad  def_rad  rep_ext  kp_ext  num_ker_pts  \
# 0    0.5     5.0       1.5      6.0      1.2     1.2           35
# 1    0.5     5.0       2.5      6.0      1.2     1.2           15
# 2    0.5     5.0       1.5      6.0      1.2     1.2           15
# 3    0.5     5.0       1.5      6.0      1.2     1.2           25
# 4    0.5     5.0       1.5      5.0      1.2     1.2           15
# 5    0.5     5.0       1.5      5.0      1.2     1.2           25
# 6    0.5     5.0       2.5      6.0      1.2     1.2           35
# 7    0.5     5.0       2.5      5.0      1.2     1.2           15
# 8    0.5     5.0       1.5      5.0      1.2     1.2           35
# 9    0.5    15.0       2.5      5.0      1.2     1.2           25
# 10   0.5    15.0       2.5      5.0      1.2     1.2           15
# 4              1.0         10              100  ...    0.7402   0.0202
# 5              1.0         10              100  ...    0.8102   0.0055
# 6              1.0         10              100  ...    0.7766   0.0104
# 7              1.0         10              100  ...    0.8173   0.0159
# 8              1.0         10              100  ...    0.7621   0.0102
# 9              0.1          5              100  ...    0.9635   0.0002
# 10             0.5          5              100  ...    0.9529   0.0005
# 11             0.1         10              100  ...    0.9650   0.0004
# 12             0.5          5              100  ...    0.9620   0.0002
# 13             0.1          5              100  ...    0.9431   0.0008
# 14             1.0          5              100  ...    0.9306   0.0013
# 15             0.5         10              100  ...    0.8717   0.0057
# 16             0.1         10              100  ...    0.9651   0.0002
# 17             0.1         10              100  ...    0.9607   0.0002
# 18             1.0          5              100  ...    0.9272   0.0007
# 19             1.0         10              100  ...    0.9589   0.0003
# 20             0.5         10              100  ...    0.9570   0.0004
# 21             0.5          5              100  ...    0.9455   0.0005
# 22             0.5          5              100  ...    0.9443   0.0006
# 23             1.0          5              100  ...    0.9353   0.0014
# 24             0.1          5              100  ...    0.9634   0.0002
# 25             0.1         10              100  ...    0.8978   0.0078
# 26             0.1         10              100  ...    0.9500   0.0005
# 27             0.5         10              100  ...    0.8920   0.0052
# 28             0.5          5              100  ...    0.9452   0.0005
# 29             1.0         10              100  ...    0.9539   0.0002
# ..             ...        ...              ...  ...       ...      ...
# 115            1.0         10              100  ...    0.9684   0.0003
# 116            1.0         20              100  ...    0.9553   0.0004
# 117            1.0         20              100  ...    0.9553   0.0004
# 118            0.1         10              100  ...    0.9613   0.0004
# 119            0.1         10              100  ...    0.9644   0.0002
# 120            0.5         10              100  ...    0.9645   0.0002
# 121            0.1         20              100  ...    0.9534   0.0006
# 122            0.1         20              100  ...    0.9534   0.0006
# 123            1.0         10              100  ...    0.9616   0.0003
# 124            1.0         10              100  ...    0.9507   0.0006
# 125            0.5         10              100  ...    0.9640   0.0002
# 126            1.0         10              100  ...    0.9641   0.0002
# 127            0.5         20              100  ...    0.9593   0.0002
# 128            0.5         20              100  ...    0.9593   0.0002
# 129            0.1         10              100  ...    0.8828   0.0142
# 130            0.5         20              100  ...    0.9616   0.0004
# 131            0.5         20              100  ...    0.9616   0.0004
# 132            1.0         20              100  ...    0.9553   0.0002
# 133            1.0         20              100  ...    0.9553   0.0002
# 134            0.1          5              100  ...    0.9542   0.0003
# 135            0.1          5              100  ...    0.9597   0.0002
# 136            1.0         20              100  ...    0.9507   0.0004
# 137            1.0         20              100  ...    0.9507   0.0004
# 138            1.0         10              100  ...    0.9570   0.0004
# 139            0.5         10              100  ...    0.9521   0.0010
# 140            0.1         10              100  ...    0.9532   0.0007
# 141            0.5         10              100  ...    0.9607   0.0006
# 142            0.5         10              100  ...    0.9609   0.0005
# 143            0.5         20              100  ...    0.9567   0.0006
# 144            0.5         20              100  ...    0.9567   0.0006
#
#         mIoU_aver IoU_other_aver  IoU_ground_aver  IoU_bui_aver  mIoU_var  \
# 0     (0.0, 10.0]          0.000            0.000        24.925     0.000
# 1    (10.0, 20.0]         33.260            0.006         0.237     0.000
# 2    (10.0, 20.0]         34.336            0.000         0.000     0.000
# 3    (10.0, 20.0]         34.361            0.000         0.000     0.000
# 4    (10.0, 20.0]         34.361            0.000         0.000     0.000
# 142  (80.0, 90.0]         71.166           90.095        79.554     0.000
# 143  (80.0, 90.0]         83.146           88.267        81.969     0.007
# 144  (80.0, 90.0]         83.146           88.267        81.969     0.007
#
#      IoU_other_var  IoU_ground_var  IoU_bui_var
# 0            0.000           0.000        0.000
# 1            0.000           0.000        0.002
# 2            0.000           0.000        0.000
# 3            0.000           0.000        0.000
# 4            0.000           0.000        0.000
# 5            0.000           0.000        0.000
# 6            0.000           0.000        0.000
# 7            0.000           0.000        0.000
# 8            0.000           0.000        0.005
# 9            0.000           0.000        0.000
# 10           0.000           0.000        0.000
# 11           0.001           0.000        0.000
# 12           0.000           0.000        0.000
# 13           0.000           0.000        0.000
# 14           0.000           0.000        0.000
# 15           0.000           0.000        0.000
# 16           0.000           0.000        0.000
# 17           0.000           0.000        0.000
# 18           0.000           0.000        0.000
# 19           0.000           0.000        0.000
# 20           0.000           0.000        0.000
# 21           0.000           0.000        0.000
# 22           0.000           0.000        0.000
# 23           0.000           0.000        0.000
# 24           0.000           0.000        0.000
# 25           0.003           0.000        0.000
# 26           0.001           0.007        0.000
# 27           0.004           0.000        0.000
# 28           0.000           0.000        0.000
# 29           0.000           0.000        0.000
# ..             ...             ...          ...
# 115          0.000           0.004        0.001
# 116          0.003           0.001        0.000
# 117          0.003           0.001        0.000
# 118          0.000           0.004        0.001
# 119          0.000           0.008        0.002
# 120          0.000           0.004        0.001
# 121          0.002           0.001        0.000
# 122          0.002           0.001        0.000
# 123          0.000           0.002        0.000
# 124          0.000           0.005        0.001
# 125          0.000           0.002        0.001
# 126          0.000           0.003        0.001
# 127          0.002           0.013        0.005
# 128          0.002           0.013        0.005
# 129          0.001           0.016        0.012
# 130          0.002           0.054        0.035
# 131          0.002           0.054        0.035
# 132          0.005           0.041        0.016
# 133          0.005           0.041        0.016
# 134          0.000           0.000        0.000
# 135          0.000           0.000        0.000
# 136          0.003           0.007        0.010
# 137          0.003           0.007        0.010
# 138          0.000           0.007        0.004
# 139          0.000           0.000        0.000
# 140          0.000           0.000        0.001
# 141          0.000           0.001        0.001
# 142          0.000           0.000        0.001
# 143          0.003           0.007        0.015
# 144          0.003           0.007        0.015
#
# [145 rows x 21 columns]
# ['fsd', 'in_rad', 'conv_rad', 'def_rad', 'rep_ext', 'kp_ext', 'num_ker_pts', 'def_fit_power']
# /usr/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# min_val, max_val, val_range 0.0 0.5 0.5
# norm_min, norm_range, norm_step 0.038 1.034 0.2068
# min_val, max_val, val_range 0.0 25.0 25.0
# norm_min, norm_range, norm_step 0.038 1.024 0.2048
# min_val, max_val, val_range 0.0 2.5 2.5
# norm_min, norm_range, norm_step 0.038 1.031 0.2062
# min_val, max_val, val_range 0.0 6.0 6.0
# norm_min, norm_range, norm_step 0.038 1.031 0.2062
# min_val, max_val, val_range 0.0 1.2 1.2
# norm_min, norm_range, norm_step 0.038 1.034 0.2068
# min_val, max_val, val_range 0.0 1.2 1.2
# norm_min, norm_range, norm_step 0.038 1.034 0.2068
# min_val, max_val, val_range 0 35 35
# norm_min, norm_range, norm_step 0.038 1.032 0.2064
# min_val, max_val, val_range 0.0 1.0 1.0
# norm_min, norm_range, norm_step 0.037000000000000005 1.0290000000000001 0.20580000000000004
